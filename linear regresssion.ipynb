# 95     4.353287   661.260624
# 96     4.005250  2547.586352
# 97     4.892935  2651.901243
# 98     4.063456  5330.535355
# 99     4.200995  3677.256894
#
# [100 rows x 2 columns]

# %%
x = df[["Engine Size"]]
x
# Out:
#     Engine Size
# 0      4.882026
# 1      4.200079
# 2      4.489369
# 3      5.120447
# 4      4.933779
# ..          ...
# 95     4.353287
# 96     4.005250
# 97     4.892935
# 98     4.063456
# 99     4.200995
#
# [100 rows x 1 columns]

# %%
y = df[["Price"]]
y
# Out:
#           Price
# 0   4771.183420
# 1  -1691.318044
# 2  -1536.480628
# 3   2943.913863
# 4  -1341.313031
# ..          ...
# 95   661.260624
# 96  2547.586352
# 97  2651.901243
# 98  5330.535355
# 99  3677.256894
#
# [100 rows x 1 columns]

# %%
model = LR()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y=model.predict(x)
y
# Out:
# array([[1559.85627783],
#        [1246.30105865],
#        [1379.31496636],
#        [1669.48049609],
#        [1583.65190115],
#        [ 929.63304724],
#        [1372.72852076],
#        [1119.50962211],
#        [1130.57647945],
#        [1248.70147933],
#        [1187.42133584],
#        [1488.63909325],
#        [1329.26635886],
#        [1182.2788752 ],
#        [1256.34893673],
#        [1231.0168526 ],
#        [1497.79026821],
#        [1107.14092801],
#        [1226.2794539 ],
#        [ 957.95223544],
#        [ 567.38180973],
#        [1304.57103747],
#        [1353.03734402],
#        [ 983.68475705],
#        [1676.11564723],
#        [ 819.95205791],
#        [1164.82590988],
#        [1111.27318941],
#        [1506.68730943],
#        [1492.10714794],
#        [1189.92809784],
#        [1241.24454861],
#        [ 950.20700808],
#        [ 698.92726771],
#        [1074.32225695],
#        [1190.25030828],
#        [1437.14614322],
#        [1430.7295304 ],
#        [1065.26094824],
#        [1084.80771483],
#        [ 913.24712846],
#        [ 827.84849513],
#        [ 762.03999887],
#        [1602.78332187],
#        [1037.13873021],
#        [1053.59426061],
#        [ 866.29244172],
#        [1333.04876711],
#        [ 783.27611114],
#        [1105.39784618],
#        [ 948.4412131 ],
#        [1243.25384223],
#        [1036.87366928],
#        [ 882.88252979],
#        [1147.8271641 ],
#        [1252.77832522],
#        [1169.59827114],
#        [1223.84351178],
#        [1008.47750804],
#        [1070.91311248],
#        [ 999.70961992],
#        [1071.64602471],
#        [ 967.36638737],
#        [ 757.43920811],
#        [1195.09588435],
#        [1061.93799161],
#        [ 779.5286774 ],
#        [1260.6983608 ],
#        [ 945.72111861],
#        [1166.24825386],
#        [1321.92180618],
#        [1183.9589372 ],
#        [1416.25081784],
#        [ 870.4235826 ],
#        [1246.80325291],
#        [ 996.87047564],
#        [ 954.11263363],
#        [1021.23044566],
#        [1082.68121903],
#        [1167.21840632],
#        [ 886.44187202],
#        [1361.40335725],
#        [1261.36050612],
#        [ 801.12855954],
#        [1496.4506869 ],
#        [1590.16515203],
#        [1425.30390051],
#        [1112.94201404],
#        [ 908.14349699],
#        [1396.72131863],
#        [1061.61705311],
#        [1435.34246198],
#        [1202.18793506],
#        [1378.83242487],
#        [1236.23368835],
#        [1316.74512784],
#        [1156.72009197],
#        [1564.87220169],
#        [1183.48286261],
#        [1246.72226537]])

# %%
MSE=mean_squared_error(y,y)
MAE=mean_absolute_error(y,y)
R2=r2_score(y,y)
print(f"Mean Squared Error= {MSE} \nMean Absolute Error = {MAE} \nR2 Score = {R2}")
# Out:
# Mean Squared Error= 0.0
# Mean Absolute Error = 0.0
# R2 Score = 1.0

# %%
plt.figure(figsize=(10,5))
plt.scatter(x,y,color='blue' , label="Actual Data")
plt.plot(x["Engine Size"],y,color='red', label="predicted Data")

plt.xlabel("Engine size")
plt.ylabel("price")
plt.title("Linear Regression")
plt.legend()

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
np.random.seed(0)
E_S=np.random.normal(3.0,0.5,100)
W_B=np.random.normal(2.0,0.5,100)
amt=1000+E_S*1000+np.random.normal(0,2000,100)
E_S
W_B
# Out:
# array([2.94157535, 1.32612047, 1.3647575 , 2.48469835, 1.4134383 ,
#        2.97181059, 1.79319051, 1.62627259, 2.96147101, 2.7402574 ,
#        2.93377948, 2.45302233, 1.56938716, 2.95503248, 1.86599831,
#        2.4012282 , 2.47362598, 1.92249495, 2.30703969, 2.46110334,
#        2.18821277, 1.4502996 , 2.14911909, 2.66319295, 1.65271607,
#        1.92518273, 1.78242322, 2.92463186, 2.33614738, 2.20373092,
#        1.61504196, 2.2696246 , 1.66283367, 2.01591528, 1.68207696,
#        2.33821665, 2.28829541, 1.89585062, 2.19800336, 1.45346925,
#        1.2543712 , 2.21969585, 2.08333675, 2.31751572, 3.19157239,
#        2.47223974, 1.54358889, 2.55850814, 1.34204629, 1.7692077 ,
#        1.9658792 , 2.85667136, 1.62762259, 1.58678073, 1.95077374,
#        1.66826086, 2.56331796, 1.46003425, 1.42626567, 1.78108998,
#        1.75098377, 2.96476603, 2.4747104 , 2.04377562, 1.38728224,
#        2.42218149, 1.49989233, 1.22761445, 2.5940149 , 2.15847131,
#        2.46042941, 2.15936383, 2.42841531, 1.6744872 , 1.48287858,
#        2.34079726, 1.59829517, 1.65522511, 1.77223375, 2.00873958,
#        1.82300304, 1.31252435, 1.6781908 , 0.88829842, 2.31261573,
#        1.19897117, 1.44780833, 2.02608254, 1.6302185 , 2.7715073 ,
#        1.35357155, 2.13352543, 1.98035859, 1.41595325, 2.26163833,
#        1.91422683, 2.38589528, 2.41175208, 3.08161797, 2.66826397])

# %%
df2 = pd.DataFrame({"Engine Size":E_S,"Wheel Base":W_B,"Amount":amt})
df2
# Out:
#     Engine Size  Wheel Base       Amount
# 0      3.882026    2.941575  4143.662497
# 1      3.200079    1.326120  3721.320249
# 2      3.489369    1.364758  6688.688184
# 3      4.120447    2.484698  6430.974061
# 4      3.933779    1.413438  6214.042047
# ..          ...         ...          ...
# 95     3.353287    1.914227  6627.069309
# 96     3.005250    2.385895  4200.699946
# 97     3.892935    2.411752  6058.842606
# 98     3.063456    3.081618  3264.557988
# 99     3.200995    2.668264  4941.106457
#
# [100 rows x 3 columns]

# %%
X1=df2[["Engine Size","Wheel Base"]]
Y1=df2["Amount"]

# %%
MLRModel=LR()
MLRModel.fit(X1,Y1)
# Out:
# LinearRegression()

# %%
y1=MLRModel.predict(X1)

# %%
MSE1=mean_squared_error(Y1,y1)
MAE1=mean_absolute_error(Y1,y1)
R21=r2_score(Y1,y1)
print(f"Mean Squared Error= {MSE1} \nMean Absolute Error = {MAE1} \nR2 Score = {R21}")
# Out:
# Mean Squared Error= 3595939.1862521726
# Mean Absolute Error = 1486.1874859297684
# R2 Score = 0.10665669047623139

# %%
X_surf,Y_surf=np.meshgrid(np.linspace(df2['Engine Size'].min(),df2['Engine Size'].max(),100),np.linspace(df2['Wheel Base'].min(),df2['Wheel Base'].max(),100))

# %%
X_surf
# Out:
# array([[1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731],
#        [1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731],
#        [1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731],
#        ...,
#        [1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731],
#        [1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731],
#        [1.72350509, 1.74786239, 1.77221968, ..., 4.08616272, 4.11052002,
#         4.13487731]])

# %%
Y_surf
# Out:
# array([[0.88829842, 0.88829842, 0.88829842, ..., 0.88829842, 0.88829842,
#         0.88829842],
#        [0.91156382, 0.91156382, 0.91156382, ..., 0.91156382, 0.91156382,
#         0.91156382],
#        [0.93482921, 0.93482921, 0.93482921, ..., 0.93482921, 0.93482921,
#         0.93482921],
#        ...,
#        [3.1450416 , 3.1450416 , 3.1450416 , ..., 3.1450416 , 3.1450416 ,
#         3.1450416 ],
#        [3.16830699, 3.16830699, 3.16830699, ..., 3.16830699, 3.16830699,
#         3.16830699],
#        [3.19157239, 3.19157239, 3.19157239, ..., 3.19157239, 3.19157239,
#         3.19157239]])

# %%
XY_surf=np.c_[X_surf.ravel(),Y_surf.ravel()]
XY_surf
# Out:
# array([[1.72350509, 0.88829842],
#        [1.74786239, 0.88829842],
#        [1.77221968, 0.88829842],
#        ...,
#        [4.08616272, 3.19157239],
#        [4.11052002, 3.19157239],
#        [4.13487731, 3.19157239]])

# %%
Z_surf=MLRModel.predict(XY_surf).reshape(X_surf.shape)
# Out:
# C:\Users\91849\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Z_surf
# Out:
# array([[2051.69064242, 2082.55780148, 2113.42496054, ..., 5045.80507147,
#         5076.67223053, 5107.53938959],
#        [2055.81195302, 2086.67911209, 2117.54627115, ..., 5049.92638208,
#         5080.79354114, 5111.6607002 ],
#        [2059.93326363, 2090.80042269, 2121.66758175, ..., 5054.04769268,
#         5084.91485174, 5115.78201081],
#        ...,
#        [2451.45777114, 2482.32493021, 2513.19208927, ..., 5445.57220019,
#         5476.43935926, 5507.30651832],
#        [2455.57908175, 2486.44624081, 2517.31339987, ..., 5449.6935108 ,
#         5480.56066986, 5511.42782893],
#        [2459.70039236, 2490.56755142, 2521.43471048, ..., 5453.81482141,
#         5484.68198047, 5515.54913953]])

# %%
fig = plt.figure()
ax= fig.add_subplot(111,projection='3d')

ax.scatter(df2["Engine Size"],df2["Wheel Base"],df2["Amount"],color='blue',label="actual data")
ax.plot_surface(X_surf,Y_surf,Z_surf,color="red",label="predicted value",alpha=0.5)
ax.set_xlabel("Engine Size")
ax.set_ylabel("Wheel Base")
ax.set_zlabel("Price")
ax.set_title("Engine Size and Wheel Base vs Price")
plt.legend()
plt.show()
