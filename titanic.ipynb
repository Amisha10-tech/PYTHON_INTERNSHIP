# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns
import os

# %%
auto = pd.read_csv("titanic.csv")
auto.head
# Out:
# <bound method NDFrame.head of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
plt.plot(auto["sex"],auto["age"])
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Sample DataFrame for demonstration purposes
data = {
    'survived': [0, 1, 1, 1, 0],
    'pclass': [3, 1, 3, 1, 3],
    'sex': ['male', 'female', 'female', 'female', 'male'],
    'age': [22.0, 38.0, 26.0, 35.0, 35.0],
    'sibsp': [1, 1, 0, 1, 0],
    'parch': [0, 0, 0, 0, 0],
    'fare': [7.25, 71.2833, 7.925, 53.1, 8.05],
    'embarked': ['S', 'C', 'S', 'S', 'S'],
    'class': ['Third', 'First', 'Third', 'First', 'Third'],
    'who': ['man', 'woman', 'woman', 'woman', 'man'],
    'adult_male': [True, False, False, False, True],
    'deck': [None, 'C', None, None, None],
    'embark_town': ['Southampton', 'Cherbourg', 'Southampton', 'Southampton', 'Southampton'],
    'alive': ['no', 'yes', 'yes', 'yes', 'no'],
    'alone': [False, False, True, False, True]
}

df = pd.DataFrame(data)

# Group by 'class' and 'sex', then unstack to create a DataFrame suitable for plotting
class_vs_sex = df.groupby(["class", "sex"]).size().unstack(fill_value=0)

# Plot stacked bar chart
plt.figure(figsize=(12, 8))
class_vs_sex.plot(kind='bar', stacked=True)
plt.title('Class vs Sex (Stacked)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Plot non-stacked bar chart
plt.figure(figsize=(12, 8))
class_vs_sex.plot(kind='bar', stacked=False)
plt.title('Class vs Sex (Non-stacked)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
print(auto.columns)

plt.figure(figsize=(12, 6))
sns.lineplot(data=auto, x="age", y="fare", linewidth=1.5)
plt.title("Fare vs Age")
plt.ylabel("Fare")
plt.xlabel("Age")
plt.show()
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 8))
sns.set(rc={"axes.facecolor":"#FFFFFF","axes.grid":False,"xtick.labelsize":10,"ytick.labelsize":10})

plt.title("Fare vs Age")
plt.ylabel("Fare")
plt.xlabel("Age")
plt.xticks(rotation=45)

sns.lineplot(x=auto["age"], y=auto["fare"], color='r')
plt.show()

# %%
class_vs_sex = auto.groupby(["class", "sex"]).size().unstack(fill_value=0)

plt.figure(figsize=(12, 8))
class_vs_sex.plot(kind='bar', stacked=True)
plt.title('Passenger Class vs Sex')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(12, 8))
class_vs_sex.plot(kind='bar', stacked=True)
plt.title('Class vs Sex (Stacked)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# Plot non-stacked bar chart
plt.figure(figsize=(12, 8))
class_vs_sex.plot(kind='bar', stacked=False)
plt.title('Class vs Sex (Non-stacked)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()
